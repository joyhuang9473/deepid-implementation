# %% [markdown]
# # [Experiment] The classification ability of Multi-scale ConvNets #

# %% [markdown]
# ## Overview ##
#
# |Model|People|Training images|Validation images|Iteration|Top-1 accuracy|
# | ----|----|----- |----- |
# |62x62_3_e2_8460|8,460|284,466|27,498|400,000|0.59673|
# |62x62_3_e1_conventional|8,460|284,466|27,498|400,000|0.585756|

# %% [markdown]
# ## Result ##

# %% [markdown]
# ![top_1_validation_set_accuracy_iters_20160416.png](./top_1_validation_set_accuracy_iters_20160416.png)

# %% [markdown]
# ## What's the Different ##

# %% [markdown]
# ||Paper|This Experiment|
# | ----|----|----|
# |Dataset|CelebFace|CASIA-WebFace|
# |Facial point detection|[30]|custom tool|
# |Input size|31x31 or 39x31|62x62|
# |Patches|60|1|
# |(Weights) Locally shared|C3, C4|no|
#
# - [30] Y.Sun, X.Wang, andX.Tang. [Deep convolutional network cascade for facial point detection.](http://www.ee.cuhk.edu.hk/~xgwang/papers/sunWTcvpr13.pdf) In Proc. CVPR, 2013
# - [D.5.1.1 The classification ability of Multi-scale ConvNets](../../DeepID.ipynb#D.5.1.1-The-classification-ability-of-Multi-scale-ConvNets)

# %% [markdown]
# ## Process ##
#
# 1. [Train ConvNets](#Train-ConvNets)
# 5. [Parse the training log](#Parse-the-training-log)

# %% [markdown]
# ### Train ConvNets ###
#
# - [Train model_62x62_3_e2_8460](../../model_62x62_3_e2_8460/train.ipynb)
# - [Train model_62x62_3_e1_conventional](../../model_62x62_3_e1_conventional/train.ipynb)

# %% [markdown]
# ### Parse the training log ###

# %%
from IPython.display import Image

# %%
# !python $CAFFE_ROOT/tools/extra/plot_training_log.py 0 \
./top_1_validation_set_accuracy_iters_20160416.png \
./caffe-20160416-multi-scale.log \
./caffe-20160416-conventional.log

# %%
Image(filename='top_1_validation_set_accuracy_iters_20160416.png')
